# %%
# creating a class 
class Student:

    def study():
        print("Students are studing")

# %%
st_object = Student()

# %%
st_object.study()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 st_object.study()
#
# TypeError: Student.study() takes 0 positional arguments but 1 was given

# %%
# class with init method
class Car():
    def __init__(self):
        print(id(self))
        print("I will call automatically")

    def new(self):
        print("this is another method")

# %%
swift = Car()
print(id(swift))
# Out:
# 1708934239568
# I will call automatically
# 1708934239568

# %%
swift.new()
# Out:
# this is another method

# %%
#creating a class with attributes
class Student:
    def __init__(self, name, rollNumber, marks):
        self.name = name
        self.rollNumber = rollNumber
        self.marks = marks

# %%
s1 = Student("Junaid",2,98)

# %%
s1.name,s1.rollNumber,s1.marks
# Out:
# ('Junaid', 2, 98)

# %%
#create a student class
class Student:
    def __init__(self,rollNumber,name,marks):
        self.rollNumber = rollNumber
        self.name = name
        self.marks = marks

    def study(self):
        print("I am ",self.name, ", and I am studing")

    def play(self):
        print("I finished my work, now I am going to p")
