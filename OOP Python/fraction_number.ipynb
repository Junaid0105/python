# %%
class fraction_number:
    def __init__(self, num, den):
        self.num = num
        self.den = den

# this method (constructor) is call when we write print funtion
    def __str__(self):
        return "{}/{}".format(self.num, self.den)

    # addtion for fraction number
    def __add__(self, other):
        numerator = (self.num*other.den)+(self.den*other.num)
        denominator = self.den*other.den
        return "{}/{}".format(numerator,denominator)

    # method for fraction subtraction
    def __sub__(self,other):
        numerator = (self.num*other.den)-(self.den*other.num)
        denominator = self.den*self.num
        return "{}/{}".format(numerator,denominator)

    # method for multiplication
    def __mul__(self, other):
        numerator = self.num * other.num
        denominator = self.den * other.den
        return "{}/{}".format(numerator,denominator)

    # method for division
    def __truediv__(self,other):

# %%
f1 = fraction_number(2,3)
f2 = fraction_number(3,2)
print(f1+f2)
print(f1-f2)
print(f1*f2)
# Out:
# 13/6
# -5/6
# 6/6
